# %%
print('hello')
# Out:
# hello

# %%
x=10
y='hello'
print(x)
print(y)
# Out:
# 10
# hello

# %%
print(x,y)
# Out:
# 10 hello

# %%
#the value of x is = 10
print('the value of x and y is =',x,y)
# Out:
# the value of x and y is = 10 hello

# %%
#the value of x is 10 and y is hello
# sign is comment
print ('the value of x is', x, ' y is', y )
# Out:
# the value of x is 10  y is hello

# %%
print (type(x))
# Out:
# <class 'int'>

# %%
a=True
print (a)
# Out:
# True

# %%
z=10.5
print(type(z))
# Out:
# <class 'float'>

# %%
h=10,6
print(type(h))
# Out:
# <class 'tuple'>

# %%
print(h)
# Out:
# (10, 6)
